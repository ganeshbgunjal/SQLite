# %% [markdown]
# ### SQLite Practice:

# %% [markdown]
# #### Importing sqlite:

# %%
import sqlite3

# %% [markdown]
# #### Connection with db:

# %%
connection = sqlite3.connect('College.db')

# %%
connection

# %%
cursor = connection.cursor()
